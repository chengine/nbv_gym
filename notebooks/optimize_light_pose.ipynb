# %%
import os
import numpy as np
from pathlib import Path

# %%
data_path = Path(
    os.path.expanduser("/home/shared/data_nerfstudio/ShadowSplat/captures/space_laces_4pm/")
)
light_path = data_path / "light_pose.txt"

# %%
with open(light_path) as f:
    text = f.read()

# %%
np.array(eval(text))

# %%
np.loadtxt(data_path / "light_pose.txt", delimiter=",")
